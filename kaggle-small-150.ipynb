# %%
import os
import glob
import shutil
from sklearn.model_selection import train_test_split
from tqdm import tqdm # For a nice progress bar

# --- 1. Define Paths ---
image_dir = "/kaggle/input/acne04-yolov8/Images"
label_dir = "/kaggle/input/acne04-yolov8/labels/content/labels"
output_dir = "/kaggle/working/acne_dataset" # This is where the new dataset will be created

# Define split ratios
# We'll do 70% train, 20% validation, 10% test
train_ratio = 0.7
val_ratio = 0.2
test_ratio = 0.1

# --- 2. Find and Match Files ---
print("Starting to find and match image/label pairs...")
image_paths = []
label_paths = []

# Supported image extensions
extensions = ['.jpg', '.jpeg', '.png']

for img_path in sorted(glob.glob(os.path.join(image_dir, "*.*"))):
    if not img_path.lower().endswith(tuple(extensions)):
        continue # Skip non-image files
        
    # Derive the corresponding label path
    file_name = os.path.basename(img_path)
    base_name = os.path.splitext(file_name)[0]
    label_path = os.path.join(label_dir, f"{base_name}.txt")
    
    # **Crucial Check: Make sure the label file exists**
    if os.path.exists(label_path):
        image_paths.append(img_path)
        label_paths.append(label_path)
    else:
        print(f"Warning: Missing label for {img_path}")

print(f"Found {len(image_paths)} matching image/label pairs.")
if len(image_paths) == 0:
    print("Error: No matching pairs found. Check your paths and file names.")
else:
    # --- 3. Create New Directory Structure ---
    sets = ['train', 'val', 'test']
    for s in sets:
        os.makedirs(os.path.join(output_dir, 'images', s), exist_ok=True)
        os.makedirs(os.path.join(output_dir, 'labels', s), exist_ok=True)
    print(f"Created directory structure at {output_dir}")

    # --- 4. Split the Data ---
    # First split: (train + val) and (test)
    train_val_img, test_img, train_val_lbl, test_lbl = train_test_split(
        image_paths, label_paths, test_size=test_ratio, random_state=42
    )
    
    # Second split: (train) and (val) from the (train + val) set
    # Note: We calculate the validation size relative to the train_val set
    val_size_relative = val_ratio / (train_ratio + val_ratio)
    train_img, val_img, train_lbl, val_lbl = train_test_split(
        train_val_img, train_val_lbl, test_size=val_size_relative, random_state=42
    )
    
    print(f"Total pairs: {len(image_paths)}")
    print(f"Training set: {len(train_img)} pairs")
    print(f"Validation set: {len(val_img)} pairs")
    print(f"Test set: {len(test_img)} pairs")

    # --- 5. Copy Files to New Structure ---
    def copy_files(image_list, label_list, set_name):
        img_dest = os.path.join(output_dir, 'images', set_name)
        lbl_dest = os.path.join(output_dir, 'labels', set_name)
        
        print(f"\nCopying {set_name} files...")
        for img_path, lbl_path in tqdm(zip(image_list, label_list), total=len(image_list)):
            shutil.copy(img_path, img_dest)
            shutil.copy(lbl_path, lbl_dest)

    # Copy files for each set
    copy_files(train_img, train_lbl, 'train')
    copy_files(val_img, val_lbl, 'val')
    copy_files(test_img, test_lbl, 'test')
    
    print("\nData splitting and copying complete!")
# Out:
# Starting to find and match image/label pairs...
# Found 1457 matching image/label pairs.
# Created directory structure at /kaggle/working/acne_dataset
# Total pairs: 1457
# Training set: 1019 pairs
# Validation set: 292 pairs
# Test set: 146 pairs
#
# Copying train files...
# 100%|██████████| 1019/1019 [00:30<00:00, 33.79it/s]
# Copying val files...
# 100%|██████████| 292/292 [00:09<00:00, 31.31it/s]
# Copying test files...
# 100%|██████████| 146/146 [00:05<00:00, 28.84it/s]
# Data splitting and copying complete!

# %%
# --- 6. Create the data.yaml file ---

# PLEASE EDIT THIS LIST
class_names = [
    'pimple'
] # e.g., ['pimple', 'blackhead', 'whitehead']

yaml_content = f"""
path: {output_dir}  # dataset root directory
train: images/train  # train images (relative to 'path')
val: images/val      # val images (relative to 'path')
test: images/test    # test images (relative to 'path')

# Classes
names:
  {os.linesep.join([f'  {i}: {name}' for i, name in enumerate(class_names)])}
"""

yaml_path = os.path.join(output_dir, 'data.yaml')
with open(yaml_path, 'w') as f:
    f.write(yaml_content)

print(f"Created data.yaml at {yaml_path}")
print("\n--- PLEASE READ ---")
print(f"Before you train, you MUST edit the 'names' section in {yaml_path}")
print("Replace 'class_0_name', etc., with your actual class names.")
print("You can edit it using the Kaggle file editor in the right-hand sidebar.")
# Out:
# Created data.yaml at /kaggle/working/acne_dataset/data.yaml
#
# --- PLEASE READ ---
# Before you train, you MUST edit the 'names' section in /kaggle/working/acne_dataset/data.yaml
# Replace 'class_0_name', etc., with your actual class names.
# You can edit it using the Kaggle file editor in the right-hand sidebar.

# %%
# Install the ultralytics library
# !pip install ultralytics -q

from ultralytics import YOLO

# --- 7. Train the Model ---

# Load a pretrained model (e.g., yolov8n.pt for small, yolov8m.pt for medium)
model = YOLO('yolov8s.pt') 

# Define the path to your newly created YAML file
data_yaml_path = '/kaggle/working/acne_dataset/data.yaml'

# Start training!
print("Starting model training...")
results = model.train(
    data=data_yaml_path,
    epochs=150,       # Start with 50-100 epochs, increase later
    imgsz=640,       # Image size (640 is common)
    batch=16,        # Adjust based on your GPU memory
    name='yolov8n_acne_custom' # Name for the results folder
)

print("Training complete!")
print(f"Results saved to: {results.save_dir}")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 21.5 MB/s eta 0:00:0000:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 67.7 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 79.0 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 55.4 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 44.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.8 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 7.5 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 27.7 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 12.6 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.9 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 63.8 MB/s eta 0:00:00:00:0100:01
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# gensim 4.3.3 requires numpy<2.0,>=1.18.5, but you have numpy 2.2.6 which is incompatible.
# gensim 4.3.3 requires scipy<1.14.0,>=1.7.0, but you have scipy 1.15.3 which is incompatible.
# mkl-umath 0.1.1 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.2.6 which is incompatible.
# mkl-random 1.2.4 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.2.6 which is incompatible.
# mkl-fft 1.3.8 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.2.6 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.2.6 which is incompatible.
# datasets 4.1.1 requires pyarrow>=21.0.0, but you have pyarrow 19.0.1 which is incompatible.
# onnx 1.18.0 requires protobuf>=4.25.1, but you have protobuf 3.20.3 which is incompatible.
# ydata-profiling 4.17.0 requires numpy<2.2,>=1.16.0, but you have numpy 2.2.6 which is incompatible.
# google-colab 1.0.0 requires google-auth==2.38.0, but you have google-auth 2.40.3 which is incompatible.
# google-colab 1.0.0 requires notebook==6.5.7, but you have notebook 6.5.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.32.5 which is incompatible.
# google-colab 1.0.0 requires tornado==6.4.2, but you have tornado 6.5.2 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# bigframes 2.12.0 requires google-cloud-bigquery[bqstorage,pandas]>=3.31.0, but you have google-cloud-bigquery 3.25.0 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.1.0 which is incompatible.
# libcugraph-cu12 25.6.0 requires libraft-cu12==25.6.*, but you have libraft-cu12 25.2.0 which is incompatible.
# gradio 5.38.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.0a1 which is incompatible.
# imbalanced-learn 0.13.0 requires scikit-learn<2,>=1.3.2, but you have scikit-learn 1.2.2 which is incompatible.
# pandas-gbq 0.29.2 requires google-api-core<3.0.0,>=2.10.2, but you have google-api-core 1.34.1 which is incompatible.
# transformers 4.53.3 requires huggingface-hub<1.0,>=0.30.0, but you have huggingface-hub 1.0.0rc2 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.2 which is incompatible.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 2.2.6 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# umap-learn 0.5.9.post2 requires scikit-learn>=1.6, but you have scikit-learn 1.2.2 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8s.pt to 'yolov8s.pt': 100% ━━━━━━━━━━━━ 21.5MB 160.0MB/s 0.1s0.1s<0.1s
# Starting model training...
# Ultralytics 8.3.224 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/acne_dataset/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=150, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8s.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=yolov8n_acne_custom, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/detect/yolov8n_acne_custom, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 15.1MB/s 0.0s
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2116435  ultralytics.nn.modules.head.Detect           [1, [128, 256, 512]]
# Model summary: 129 layers, 11,135,987 parameters, 11,135,971 gradients, 28.6 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 68.5MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4534.4±1130.1 MB/s, size: 878.2 KB)
# train: Scanning /kaggle/working/acne_dataset/labels/train... 1019 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1019/1019 1.1Kit/s 0.9s<0.0s
# train: New cache created: /kaggle/working/acne_dataset/labels/train.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1022.1±1182.0 MB/s, size: 889.6 KB)
# val: Scanning /kaggle/working/acne_dataset/labels/val... 292 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 292/292 980.7it/s 0.3s0.2s
# val: New cache created: /kaggle/working/acne_dataset/labels/val.cache
# Plotting labels to /kaggle/working/runs/detect/yolov8n_acne_custom/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /kaggle/working/runs/detect/yolov8n_acne_custom
# Starting training for 150 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/150      4.27G      3.049      2.749      1.553        431        640: 100% ━━━━━━━━━━━━ 64/64 1.4it/s 46.7s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 1.8it/s 5.5s.4s
#                    all        292       3874      0.155      0.292      0.102     0.0251
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/150      4.96G       2.81      1.978      1.408        201        640: 100% ━━━━━━━━━━━━ 64/64 1.3it/s 47.8s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.7it/s 3.7s.

#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     145/150      7.22G       2.28      1.423      1.285        200        640: 100% ━━━━━━━━━━━━ 64/64 1.3it/s 50.3s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.4it/s 4.2s.5ss
#                    all        292       3874      0.436      0.403       0.31     0.0754
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     146/150      7.26G      2.275      1.413      1.279        141        640: 100% ━━━━━━━━━━━━ 64/64 1.2it/s 53.4s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.4it/s 4.1s.5s
#                    all        292       3874      0.434      0.398      0.306     0.0754
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     147/150      7.29G      2.272      1.427       1.29         83        640: 100% ━━━━━━━━━━━━ 64/64 1.4it/s 46.8s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.8it/s 3.6s.4ss
#                    all        292       3874      0.428      0.393        0.3     0.0735
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     148/150      7.33G      2.267      1.402      1.272        120        640: 100% ━━━━━━━━━━━━ 64/64 1.3it/s 50.4s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.0it/s 3.4s.4ss
#                    all        292       3874       0.44      0.406      0.312     0.0763
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     149/150      7.37G      2.264      1.404      1.273        217        640: 100% ━━━━━━━━━━━━ 64/64 1.8it/s 34.9s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.6it/s 3.9s.4ss
#                    all        292       3874      0.434      0.399      0.304     0.0753
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     150/150      3.95G      2.278      1.425      1.288        128        640: 100% ━━━━━━━━━━━━ 64/64 1.3it/s 48.1s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.7it/s 3.7s.4s
#                    all        292       3874      0.433      0.403      0.307     0.0756
#
# 150 epochs completed in 2.251 hours.
# Optimizer stripped from /kaggle/working/runs/detect/yolov8n_acne_custom/weights/last.pt, 22.5MB
# Optimizer stripped from /kaggle/working/runs/detect/yolov8n_acne_custom/weights/best.pt, 22.5MB
#
# Validating /kaggle/working/runs/detect/yolov8n_acne_custom/weights/best.pt...
# Ultralytics 8.3.224 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.8it/s 12.2s.6s
# /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
#                    all        292       3874      0.437      0.398      0.326     0.0855
# Speed: 0.2ms preprocess, 5.0ms inference, 0.0ms loss, 2.3ms postprocess per image
# Results saved to /kaggle/working/runs/detect/yolov8n_acne_custom
# Training complete!
# Results saved to: /kaggle/working/runs/detect/yolov8n_acne_custom

# %%
import shutil
from IPython.display import FileLink

# Define paths
image_dir = '/kaggle/working/acne_dataset/images/test'
label_dir = '/kaggle/working/acne_dataset/labels/test'
zip_path = '/kaggle/working/acne_test.zip'

# Create a temporary folder to combine both
combined_dir = '/kaggle/working/acne_test_combined'

# Copy both folders into one combined directory
shutil.copytree(image_dir, f'{combined_dir}/images')
shutil.copytree(label_dir, f'{combined_dir}/labels')

# Zip the combined directory
shutil.make_archive('/kaggle/working/acne_test', 'zip', combined_dir)

# Provide download link
FileLink(zip_path)
# Out:
# /kaggle/working/acne_test.zip

# %%
import shutil
from IPython.display import FileLink

# Define paths
image_dir = '/kaggle/working/acne_dataset/images/train'
label_dir = '/kaggle/working/acne_dataset/labels/train'
zip_path = '/kaggle/working/acne_train.zip'

# Create a temporary folder to combine both
combined_dir = '/kaggle/working/acne_train_combined'

# Copy both folders into one combined directory
shutil.copytree(image_dir, f'{combined_dir}/images')
shutil.copytree(label_dir, f'{combined_dir}/labels')

# Zip the combined directory
shutil.make_archive('/kaggle/working/acne_train', 'zip', combined_dir)

# Provide download link
FileLink(zip_path)
# Out:
# /kaggle/working/acne_train.zip

# %%
import shutil
from IPython.display import FileLink

# Define paths
image_dir = '/kaggle/working/acne_dataset/images/val'
label_dir = '/kaggle/working/acne_dataset/labels/val'
zip_path = '/kaggle/working/acne_valid.zip'

# Create a temporary folder to combine both
combined_dir = '/kaggle/working/acne_valid_combined'

# Copy both folders into one combined directory
shutil.copytree(image_dir, f'{combined_dir}/images')
shutil.copytree(label_dir, f'{combined_dir}/labels')

# Zip the combined directory
shutil.make_archive('/kaggle/working/acne_valid', 'zip', combined_dir)

# Provide download link
FileLink(zip_path)
# Out:
# /kaggle/working/acne_valid.zip

# %%
from ultralytics import YOLO

# Load your BEST model
model = YOLO('/kaggle/working/runs/detect/yolov8n_acne_custom/weights/best.pt')

# Run prediction on your test images and save the results
results = model.predict(
    source='/kaggle/working/acne_dataset/images/test/', 
    save=True
)

print("Predictions saved! Check the /kaggle/working/runs/detect/predict/ folder.")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 23.3 MB/s eta 0:00:0000:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 104.0 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.8 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 108.3 MB/s eta 0:00:0000:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 78.6 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 49.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 2.1 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.3 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.1 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 207.5/207.5 MB 204.1 MB/s eta 0:00:0100:01
# image 1/146 /kaggle/working/acne_dataset/images/test/levle0_111.jpg: 640x576 1 pimple, 53.9ms
# image 2/146 /kaggle/working/acne_dataset/images/test/levle0_124.jpg: 640x576 2 pimples, 15.6ms
# image 3/146 /kaggle/working/acne_dataset/images/test/levle0_138.jpg: 640x576 1 pimple, 15.6ms
# image 4/146 /kaggle/working/acne_dataset/images/test/levle0_139.jpg: 640x576 1 pimple, 15.6ms
# image 5/146 /kaggle/working/acne_dataset/images/test/levle0_143.jpg: 640x576 (no detections), 15.6ms
# image 6/146 /kaggle/working/acne_dataset/images/test/levle0_145.jpg: 640x576 2 pimples, 15.6ms
# image 7/146 /kaggle/working/acne_dataset/images/test/levle0_152.jpg: 640x576 (no detections), 15.6ms
# image 8/146 /kaggle/working/acne_dataset/images/test/levle0_158.jpg: 640x576 (no detections), 15.6ms
# image 9/146 /kaggle/working/acne_dataset/images/test/levle0_16.jpg: 640x576 1 pimple, 16.2ms
# image 10/146 /kaggle/working/acne_dataset/images/test/levle0_162.jpg: 640x576 (no detections), 15.6ms
# image 11/146 /kaggle/working/acne_dataset/images/test/levle0_168.jpg: 640x576 1 pimple, 15.6ms
# image 12/146 /kaggle/working/acne_dataset/images/test/levle0_17.jpg: 480x640 4 pimples, 48.9ms
# image 13/146 /kaggle/working/acne_dataset/images/test/levle0_190.jpg: 640x576 (no detections), 16.6ms
# image 14/146 /kaggle/working/acne_dataset/images/test/levle0_206.jpg: 640x576 (no detections), 15.8ms
# image 15/146 /kaggle/working/acne_dataset/images/test/levle0_214.jpg: 640x576 4 pimples, 15.6ms
# image 16/146 /kaggle/working/acne_dataset/images/test/levle0_230.jpg: 640x576 2 pimples, 15.6ms
# image 17/146 /kaggle/working/acne_dataset/images/test/levle0_257.jpg: 640x576 (no detections), 15.6ms
# image 18/146 /kaggle/working/acne_dataset/images/test/levle0_264.jpg: 640x576 1 pimple, 15.5ms
# image 19/146 /kaggle/working/acne_dataset/images/test/levle0_272.jpg: 640x576 2 pimples, 15.6ms
# image 20/146 /kaggle/working/acne_dataset/images/test/levle0_28.jpg: 640x576 (no detections), 15.6ms
# image 21/146 /kaggle/working/acne_dataset/images/test/levle0_285.jpg: 640x576 (no detections), 15.6ms
# image 22/146 /kaggle/working/acne_dataset/images/test/levle0_290.jpg: 640x576 1 pimple, 16.2ms
# image 23/146 /kaggle/working/acne_dataset/images/test/levle0_304.jpg: 640x576 (no detections), 15.6ms
# image 24/146 /kaggle/working/acne_dataset/images/test/levle0_306.jpg: 640x576 1 pimple, 15.6ms
# image 25/146 /kaggle/working/acne_dataset/images/test/levle0_316.jpg: 640x576 1 pimple, 15.6ms
# image 26/146 /kaggle/working/acne_dataset/images/test/levle0_328.jpg: 640x576 4 pimples, 15.6ms
# image 27/146 /kaggle/working/acne_dataset/images/test/levle0_342.jpg: 640x576 (no detections), 15.7ms
# image 28/146 /kaggle/working/acne_dataset/images/test/levle0_355.jpg: 640x576 1 pimple, 15.6ms
# image 29/146 /kaggle/working/acne_dataset/images/test/levle0_359.jpg: 640x576 (no detections), 15.6ms
# image 30/146 /kaggle/working/acne_dataset/images/test/levle0_36.jpg: 640x576 2 pimples, 15.6ms
# image 31/146 /kaggle/working/acne_dataset/images/test/levle0_361.jpg: 640x576 (no detections), 15.6ms
# image 32/146 /kaggle/working/acne_dataset/images/test/levle0_399.jpg: 640x576 2 pimples, 15.6ms
# image 33/146 /kaggle/working/acne_dataset/images/test/levle0_403.jpg: 640x576 1 pimple, 15.6ms
# image 34/146 /kaggle/working/acne_dataset/images/test/levle0_413.jpg: 640x576 (no detections), 15.6ms
# image 35/146 /kaggle/working/acne_dataset/images/test/levle0_43.jpg: 640x576 (no detections), 17.2ms
# image 36/146 /kaggle/working/acne_dataset/images/test/levle0_441.jpg: 640x576 1 pimple, 15.5ms
# image 37/146 /kaggle/working/acne_dataset/images/test/levle0_450.jpg: 640x576 2 pimples, 15.5ms
# image 38/146 /kaggle/working/acne_dataset/images/test/levle0_462.jpg: 640x576 2 pimples, 15.5ms
# image 39/146 /kaggle/working/acne_dataset/images/test/levle0_465.jpg: 640x576 2 pimples, 15.6ms
# image 40/146 /kaggle/working/acne_dataset/images/test/levle0_477.jpg: 640x576 2 pimples, 15.6ms
# image 41/146 /kaggle/working/acne_dataset/images/test/levle0_482.jpg: 640x576 (no detections), 15.6ms
# image 42/146 /kaggle/working/acne_dataset/images/test/levle0_489.jpg: 640x576 1 pimple, 15.5ms
# image 43/146 /kaggle/working/acne_dataset/images/test/levle0_495.jpg: 640x576 1 pimple, 15.6ms
# image 44/146 /kaggle/working/acne_dataset/images/test/levle0_497.jpg: 640x576 (no detections), 15.6ms
# image 45/146 /kaggle/working/acne_dataset/images/test/levle0_499.jpg: 640x576 (no detections), 15.6ms
# image 46/146 /kaggle/working/acne_dataset/images/test/levle0_5.jpg: 640x448 1 pimple, 49.2ms
# image 47/146 /kaggle/working/acne_dataset/images/test/levle0_504.jpg: 640x576 4 pimples, 16.7ms
# image 48/146 /kaggle/working/acne_dataset/images/test/levle0_506.jpg: 640x576 2 pimples, 15.6ms
# image 49/146 /kaggle/working/acne_dataset/images/test/levle0_509.jpg: 640x576 2 pimples, 15.6ms
# image 50/146 /kaggle/working/acne_dataset/images/test/levle0_510.jpg: 640x576 1 pimple, 15.6ms
# image 51/146 /kaggle/working/acne_dataset/images/test/levle0_511.jpg: 640x576 2 pimples, 15.6ms
# image 52/146 /kaggle/working/acne_dataset/images/test/levle0_516.jpg: 640x576 3 pimples, 15.6ms
# image 53/146 /kaggle/working/acne_dataset/images/test/levle0_54.jpg: 640x576 3 pimples, 15.5ms
# image 54/146 /kaggle/working/acne_dataset/images/test/levle0_56.jpg: 448x640 (no detections), 47.3ms
# image 55/146 /kaggle/working/acne_dataset/images/test/levle0_64.jpg: 448x640 2 pimples, 12.8ms
# image 56/146 /kaggle/working/acne_dataset/images/test/levle1_0.jpg: 640x480 1 pimple, 49.3ms
# image 57/146 /kaggle/working/acne_dataset/images/test/levle1_106.jpg: 448x640 1 pimple, 14.2ms
# image 58/146 /kaggle/working/acne_dataset/images/test/levle1_149.jpg: 640x576 1 pimple, 16.9ms
# image 59/146 /kaggle/working/acne_dataset/images/test/levle1_161.jpg: 640x576 2 pimples, 15.6ms
# image 60/146 /kaggle/working/acne_dataset/images/test/levle1_166.jpg: 640x576 2 pimples, 15.6ms
# image 61/146 /kaggle/working/acne_dataset/images/test/levle1_17.jpg: 640x480 12 pimples, 12.8ms
# image 62/146 /kaggle/working/acne_dataset/images/test/levle1_172.jpg: 640x576 2 pimples, 16.7ms
# image 63/146 /kaggle/working/acne_dataset/images/test/levle1_176.jpg: 640x576 5 pimples, 15.7ms
# image 64/146 /kaggle/working/acne_dataset/images/test/levle1_177.jpg: 640x576 1 pimple, 15.6ms
# image 65/146 /kaggle/working/acne_dataset/images/test/levle1_182.jpg: 640x576 3 pimples, 15.7ms
# image 66/146 /kaggle/working/acne_dataset/images/test/levle1_199.jpg: 640x576 (no detections), 15.6ms
# image 67/146 /kaggle/working/acne_dataset/images/test/levle1_203.jpg: 640x576 6 pimples, 15.6ms
# image 68/146 /kaggle/working/acne_dataset/images/test/levle1_205.jpg: 640x576 5 pimples, 15.6ms
# image 69/146 /kaggle/working/acne_dataset/images/test/levle1_208.jpg: 640x576 2 pimples, 15.6ms
# image 70/146 /kaggle/working/acne_dataset/images/test/levle1_210.jpg: 640x576 6 pimples, 15.6ms
# image 71/146 /kaggle/working/acne_dataset/images/test/levle1_222.jpg: 640x576 4 pimples, 15.6ms
# image 72/146 /kaggle/working/acne_dataset/images/test/levle1_247.jpg: 640x576 3 pimples, 15.6ms
# image 73/146 /kaggle/working/acne_dataset/images/test/levle1_253.jpg: 640x576 3 pimples, 15.5ms
# image 74/146 /kaggle/working/acne_dataset/images/test/levle1_257.jpg: 448x640 15 pimples, 13.6ms
# image 75/146 /kaggle/working/acne_dataset/images/test/levle1_261.jpg: 448x640 4 pimples, 13.0ms
# image 76/146 /kaggle/working/acne_dataset/images/test/levle1_264.jpg: 448x640 8 pimples, 12.9ms
# image 77/146 /kaggle/working/acne_dataset/images/test/levle1_266.jpg: 448x640 4 pimples, 15.0ms
# image 78/146 /kaggle/working/acne_dataset/images/test/levle1_288.jpg: 640x576 2 pimples, 16.6ms
# image 79/146 /kaggle/working/acne_dataset/images/test/levle1_295.jpg: 640x576 5 pimples, 15.6ms
# image 80/146 /kaggle/working/acne_dataset/images/test/levle1_300.jpg: 640x576 3 pimples, 15.6ms
# image 81/146 /kaggle/working/acne_dataset/images/test/levle1_321.jpg: 640x576 3 pimples, 15.6ms
# image 82/146 /kaggle/working/acne_dataset/images/test/levle1_335.jpg: 640x576 4 pimples, 15.6ms
# image 83/146 /kaggle/working/acne_dataset/images/test/levle1_345.jpg: 640x576 2 pimples, 15.6ms
# image 84/146 /kaggle/working/acne_dataset/images/test/levle1_371.jpg: 640x576 2 pimples, 15.7ms
# image 85/146 /kaggle/working/acne_dataset/images/test/levle1_378.jpg: 640x576 2 pimples, 15.6ms
# image 86/146 /kaggle/working/acne_dataset/images/test/levle1_381.jpg: 640x576 1 pimple, 15.6ms
# image 87/146 /kaggle/working/acne_dataset/images/test/levle1_402.jpg: 640x576 3 pimples, 15.6ms
# image 88/146 /kaggle/working/acne_dataset/images/test/levle1_404.jpg: 640x576 3 pimples, 15.6ms
# image 89/146 /kaggle/working/acne_dataset/images/test/levle1_411.jpg: 640x576 2 pimples, 15.6ms
# image 90/146 /kaggle/working/acne_dataset/images/test/levle1_421.jpg: 640x576 4 pimples, 15.6ms
# image 91/146 /kaggle/working/acne_dataset/images/test/levle1_427.jpg: 640x576 8 pimples, 15.6ms
# image 92/146 /kaggle/working/acne_dataset/images/test/levle1_43.jpg: 640x576 3 pimples, 15.7ms
# image 93/146 /kaggle/working/acne_dataset/images/test/levle1_44.jpg: 640x576 4 pimples, 15.6ms
# image 94/146 /kaggle/working/acne_dataset/images/test/levle1_446.jpg: 640x576 7 pimples, 15.6ms
# image 95/146 /kaggle/working/acne_dataset/images/test/levle1_45.jpg: 640x576 6 pimples, 15.6ms
# image 96/146 /kaggle/working/acne_dataset/images/test/levle1_467.jpg: 640x576 4 pimples, 15.8ms
# image 97/146 /kaggle/working/acne_dataset/images/test/levle1_471.jpg: 640x576 2 pimples, 15.6ms
# image 98/146 /kaggle/working/acne_dataset/images/test/levle1_472.jpg: 640x576 1 pimple, 15.7ms
# image 99/146 /kaggle/working/acne_dataset/images/test/levle1_485.jpg: 640x576 8 pimples, 15.8ms
# image 100/146 /kaggle/working/acne_dataset/images/test/levle1_509.jpg: 640x576 4 pimples, 15.6ms
# image 101/146 /kaggle/working/acne_dataset/images/test/levle1_56.jpg: 640x576 10 pimples, 15.7ms
# image 102/146 /kaggle/working/acne_dataset/images/test/levle1_575.jpg: 640x576 4 pimples, 15.7ms
# image 103/146 /kaggle/working/acne_dataset/images/test/levle1_584.jpg: 640x576 5 pimples, 15.7ms
# image 104/146 /kaggle/working/acne_dataset/images/test/levle1_585.jpg: 640x576 6 pimples, 15.7ms
# image 105/146 /kaggle/working/acne_dataset/images/test/levle1_597.jpg: 640x576 2 pimples, 15.6ms
# image 106/146 /kaggle/working/acne_dataset/images/test/levle1_599.jpg: 640x576 10 pimples, 15.6ms
# image 107/146 /kaggle/working/acne_dataset/images/test/levle1_600.jpg: 640x576 3 pimples, 15.6ms
# image 108/146 /kaggle/working/acne_dataset/images/test/levle1_607.jpg: 640x576 3 pimples, 15.6ms
# image 109/146 /kaggle/working/acne_dataset/images/test/levle1_615.jpg: 640x576 3 pimples, 15.6ms
# image 110/146 /kaggle/working/acne_dataset/images/test/levle1_625.jpg: 640x576 15 pimples, 15.7ms
# image 111/146 /kaggle/working/acne_dataset/images/test/levle1_626.jpg: 640x576 7 pimples, 15.8ms
# image 112/146 /kaggle/working/acne_dataset/images/test/levle1_67.jpg: 640x576 4 pimples, 15.6ms
# image 113/146 /kaggle/working/acne_dataset/images/test/levle1_78.jpg: 448x640 8 pimples, 13.9ms
# image 114/146 /kaggle/working/acne_dataset/images/test/levle1_8.jpg: 640x544 4 pimples, 51.0ms
# image 115/146 /kaggle/working/acne_dataset/images/test/levle1_84.jpg: 448x640 14 pimples, 13.7ms
# image 116/146 /kaggle/working/acne_dataset/images/test/levle1_97.jpg: 448x640 1 pimple, 12.8ms
# image 117/146 /kaggle/working/acne_dataset/images/test/levle1_98.jpg: 448x640 6 pimples, 12.7ms
# image 118/146 /kaggle/working/acne_dataset/images/test/levle2_109.jpg: 640x576 10 pimples, 16.6ms
# image 119/146 /kaggle/working/acne_dataset/images/test/levle2_124.jpg: 640x576 10 pimples, 15.5ms
# image 120/146 /kaggle/working/acne_dataset/images/test/levle2_13.jpg: 640x576 4 pimples, 15.5ms
# image 121/146 /kaggle/working/acne_dataset/images/test/levle2_153.jpg: 640x576 9 pimples, 15.5ms
# image 122/146 /kaggle/working/acne_dataset/images/test/levle2_156.jpg: 640x576 7 pimples, 15.6ms
# image 123/146 /kaggle/working/acne_dataset/images/test/levle2_158.jpg: 640x576 5 pimples, 15.6ms
# image 124/146 /kaggle/working/acne_dataset/images/test/levle2_159.jpg: 640x576 4 pimples, 15.6ms
# image 125/146 /kaggle/working/acne_dataset/images/test/levle2_16.jpg: 640x480 1 pimple, 13.0ms
# image 126/146 /kaggle/working/acne_dataset/images/test/levle2_163.jpg: 640x576 11 pimples, 16.4ms
# image 127/146 /kaggle/working/acne_dataset/images/test/levle2_172.jpg: 640x576 8 pimples, 15.8ms
# image 128/146 /kaggle/working/acne_dataset/images/test/levle2_177.jpg: 640x576 15 pimples, 15.6ms
# image 129/146 /kaggle/working/acne_dataset/images/test/levle2_22.jpg: 640x480 8 pimples, 13.5ms
# image 130/146 /kaggle/working/acne_dataset/images/test/levle2_30.jpg: 640x544 18 pimples, 17.1ms
# image 131/146 /kaggle/working/acne_dataset/images/test/levle2_45.jpg: 448x640 7 pimples, 13.7ms
# image 132/146 /kaggle/working/acne_dataset/images/test/levle2_53.jpg: 448x640 13 pimples, 12.8ms
# image 133/146 /kaggle/working/acne_dataset/images/test/levle2_59.jpg: 448x640 7 pimples, 12.7ms
# image 134/146 /kaggle/working/acne_dataset/images/test/levle2_87.jpg: 640x576 3 pimples, 16.5ms
# image 135/146 /kaggle/working/acne_dataset/images/test/levle2_96.jpg: 640x576 16 pimples, 15.6ms
# image 136/146 /kaggle/working/acne_dataset/images/test/levle3_0.jpg: 640x480 12 pimples, 12.7ms
# image 137/146 /kaggle/working/acne_dataset/images/test/levle3_12.jpg: 640x480 21 pimples, 11.8ms
# image 138/146 /kaggle/working/acne_dataset/images/test/levle3_131.jpg: 640x576 11 pimples, 16.2ms
# image 139/146 /kaggle/working/acne_dataset/images/test/levle3_3.jpg: 640x480 1 pimple, 12.6ms
# image 140/146 /kaggle/working/acne_dataset/images/test/levle3_40.jpg: 640x512 5 pimples, 42.4ms
# image 141/146 /kaggle/working/acne_dataset/images/test/levle3_50.jpg: 640x640 2 pimples, 17.2ms
# image 142/146 /kaggle/working/acne_dataset/images/test/levle3_55.jpg: 640x512 8 pimples, 12.8ms
# image 143/146 /kaggle/working/acne_dataset/images/test/levle3_67.jpg: 640x480 1 pimple, 13.0ms
# image 144/146 /kaggle/working/acne_dataset/images/test/levle3_73.jpg: 384x640 10 pimples, 60.8ms
# image 145/146 /kaggle/working/acne_dataset/images/test/levle3_75.jpg: 384x640 17 pimples, 10.6ms
# image 146/146 /kaggle/working/acne_dataset/images/test/levle3_92.jpg: 448x640 11 pimples, 13.8ms
# Speed: 3.9ms preprocess, 17.2ms inference, 1.6ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /kaggle/working/runs/detect/predict
# Predictions saved! Check the /kaggle/working/runs/detect/predict/ folder.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.3 MB/s eta 0:00:00:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 85.1 MB/s eta 0:00:00:00:0100:01
# ^C
# ERROR: Operation cancelled by user
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_37/1489881217.py in <cell line: 0>()
#       1 get_ipython().system('pip install ultralytics==8.3.224 --quiet')
# ----> 2 from ultralytics import YOLO
#       3
#       4 model = YOLO('/kaggle/input/test-acne04/best_final.pt')
#       5
#
# ModuleNotFoundError: No module named 'ultralytics'
# image 1/146 /kaggle/working/acne_dataset/images/test/levle0_111.jpg: 640x576 1 pimple, 53.9ms
# image 2/146 /kaggle/working/acne_dataset/images/test/levle0_124.jpg: 640x576 2 pimples, 15.6ms
# image 3/146 /kaggle/working/acne_dataset/images/test/levle0_138.jpg: 640x576 1 pimple, 15.6ms
# image 4/146 /kaggle/working/acne_dataset/images/test/levle0_139.jpg: 640x576 1 pimple, 15.6ms
# image 5/146 /kaggle/working/acne_dataset/images/test/levle0_143.jpg: 640x576 (no detections), 15.6ms
# image 6/146 /kaggle/working/acne_dataset/images/test/levle0_145.jpg: 640x576 2 pimples, 15.6ms
# image 7/146 /kaggle/working/acne_dataset/images/test/levle0_152.jpg: 640x576 (no detections), 15.6ms
# image 8/146 /kaggle/working/acne_dataset/images/test/levle0_158.jpg: 640x576 (no detections), 15.6ms
# image 9/146 /kaggle/working/acne_dataset/images/test/levle0_16.jpg: 640x576 1 pimple, 16.2ms
# image 10/146 /kaggle/working/acne_dataset/images/test/levle0_162.jpg: 640x576 (no detections), 15.6ms
# image 11/146 /kaggle/working/acne_dataset/images/test/levle0_168.jpg: 640x576 1 pimple, 15.6ms
# image 12/146 /kaggle/working/acne_dataset/images/test/levle0_17.jpg: 480x640 4 pimples, 48.9ms
# image 13/146 /kaggle/working/acne_dataset/images/test/levle0_190.jpg: 640x576 (no detections), 16.6ms
# image 14/146 /kaggle/working/acne_dataset/images/test/levle0_206.jpg: 640x576 (no detections), 15.8ms
# image 15/146 /kaggle/working/acne_dataset/images/test/levle0_214.jpg: 640x576 4 pimples, 15.6ms
# image 16/146 /kaggle/working/acne_dataset/images/test/levle0_230.jpg: 640x576 2 pimples, 15.6ms
# image 17/146 /kaggle/working/acne_dataset/images/test/levle0_257.jpg: 640x576 (no detections), 15.6ms
# image 18/146 /kaggle/working/acne_dataset/images/test/levle0_264.jpg: 640x576 1 pimple, 15.5ms
# image 19/146 /kaggle/working/acne_dataset/images/test/levle0_272.jpg: 640x576 2 pimples, 15.6ms
# image 20/146 /kaggle/working/acne_dataset/images/test/levle0_28.jpg: 640x576 (no detections), 15.6ms
# image 21/146 /kaggle/working/acne_dataset/images/test/levle0_285.jpg: 640x576 (no detections), 15.6ms
# image 22/146 /kaggle/working/acne_dataset/images/test/levle0_290.jpg: 640x576 1 pimple, 16.2ms
# image 23/146 /kaggle/working/acne_dataset/images/test/levle0_304.jpg: 640x576 (no detections), 15.6ms
# image 24/146 /kaggle/working/acne_dataset/images/test/levle0_306.jpg: 640x576 1 pimple, 15.6ms
# image 25/146 /kaggle/working/acne_dataset/images/test/levle0_316.jpg: 640x576 1 pimple, 15.6ms
# image 26/146 /kaggle/working/acne_dataset/images/test/levle0_328.jpg: 640x576 4 pimples, 15.6ms
# image 27/146 /kaggle/working/acne_dataset/images/test/levle0_342.jpg: 640x576 (no detections), 15.7ms
# image 28/146 /kaggle/working/acne_dataset/images/test/levle0_355.jpg: 640x576 1 pimple, 15.6ms
# image 29/146 /kaggle/working/acne_dataset/images/test/levle0_359.jpg: 640x576 (no detections), 15.6ms
# image 30/146 /kaggle/working/acne_dataset/images/test/levle0_36.jpg: 640x576 2 pimples, 15.6ms
# image 31/146 /kaggle/working/acne_dataset/images/test/levle0_361.jpg: 640x576 (no detections), 15.6ms
# image 32/146 /kaggle/working/acne_dataset/images/test/levle0_399.jpg: 640x576 2 pimples, 15.6ms
# image 33/146 /kaggle/working/acne_dataset/images/test/levle0_403.jpg: 640x576 1 pimple, 15.6ms
# image 34/146 /kaggle/working/acne_dataset/images/test/levle0_413.jpg: 640x576 (no detections), 15.6ms
# image 35/146 /kaggle/working/acne_dataset/images/test/levle0_43.jpg: 640x576 (no detections), 17.2ms
# image 36/146 /kaggle/working/acne_dataset/images/test/levle0_441.jpg: 640x576 1 pimple, 15.5ms
# image 37/146 /kaggle/working/acne_dataset/images/test/levle0_450.jpg: 640x576 2 pimples, 15.5ms
# image 38/146 /kaggle/working/acne_dataset/images/test/levle0_462.jpg: 640x576 2 pimples, 15.5ms
# image 39/146 /kaggle/working/acne_dataset/images/test/levle0_465.jpg: 640x576 2 pimples, 15.6ms
# image 40/146 /kaggle/working/acne_dataset/images/test/levle0_477.jpg: 640x576 2 pimples, 15.6ms
# image 41/146 /kaggle/working/acne_dataset/images/test/levle0_482.jpg: 640x576 (no detections), 15.6ms
# image 42/146 /kaggle/working/acne_dataset/images/test/levle0_489.jpg: 640x576 1 pimple, 15.5ms
# image 43/146 /kaggle/working/acne_dataset/images/test/levle0_495.jpg: 640x576 1 pimple, 15.6ms
# image 44/146 /kaggle/working/acne_dataset/images/test/levle0_497.jpg: 640x576 (no detections), 15.6ms
# image 45/146 /kaggle/working/acne_dataset/images/test/levle0_499.jpg: 640x576 (no detections), 15.6ms
# image 46/146 /kaggle/working/acne_dataset/images/test/levle0_5.jpg: 640x448 1 pimple, 49.2ms
# image 47/146 /kaggle/working/acne_dataset/images/test/levle0_504.jpg: 640x576 4 pimples, 16.7ms
# image 48/146 /kaggle/working/acne_dataset/images/test/levle0_506.jpg: 640x576 2 pimples, 15.6ms
# image 49/146 /kaggle/working/acne_dataset/images/test/levle0_509.jpg: 640x576 2 pimples, 15.6ms
# image 50/146 /kaggle/working/acne_dataset/images/test/levle0_510.jpg: 640x576 1 pimple, 15.6ms
# image 51/146 /kaggle/working/acne_dataset/images/test/levle0_511.jpg: 640x576 2 pimples, 15.6ms
# image 52/146 /kaggle/working/acne_dataset/images/test/levle0_516.jpg: 640x576 3 pimples, 15.6ms
# image 53/146 /kaggle/working/acne_dataset/images/test/levle0_54.jpg: 640x576 3 pimples, 15.5ms
# image 54/146 /kaggle/working/acne_dataset/images/test/levle0_56.jpg: 448x640 (no detections), 47.3ms
# image 55/146 /kaggle/working/acne_dataset/images/test/levle0_64.jpg: 448x640 2 pimples, 12.8ms
# image 56/146 /kaggle/working/acne_dataset/images/test/levle1_0.jpg: 640x480 1 pimple, 49.3ms
# image 57/146 /kaggle/working/acne_dataset/images/test/levle1_106.jpg: 448x640 1 pimple, 14.2ms
# image 58/146 /kaggle/working/acne_dataset/images/test/levle1_149.jpg: 640x576 1 pimple, 16.9ms
# image 59/146 /kaggle/working/acne_dataset/images/test/levle1_161.jpg: 640x576 2 pimples, 15.6ms
# image 60/146 /kaggle/working/acne_dataset/images/test/levle1_166.jpg: 640x576 2 pimples, 15.6ms
# image 61/146 /kaggle/working/acne_dataset/images/test/levle1_17.jpg: 640x480 12 pimples, 12.8ms
# image 62/146 /kaggle/working/acne_dataset/images/test/levle1_172.jpg: 640x576 2 pimples, 16.7ms
# image 63/146 /kaggle/working/acne_dataset/images/test/levle1_176.jpg: 640x576 5 pimples, 15.7ms
# image 64/146 /kaggle/working/acne_dataset/images/test/levle1_177.jpg: 640x576 1 pimple, 15.6ms
# image 65/146 /kaggle/working/acne_dataset/images/test/levle1_182.jpg: 640x576 3 pimples, 15.7ms
# image 66/146 /kaggle/working/acne_dataset/images/test/levle1_199.jpg: 640x576 (no detections), 15.6ms
# image 67/146 /kaggle/working/acne_dataset/images/test/levle1_203.jpg: 640x576 6 pimples, 15.6ms
# image 68/146 /kaggle/working/acne_dataset/images/test/levle1_205.jpg: 640x576 5 pimples, 15.6ms
# image 69/146 /kaggle/working/acne_dataset/images/test/levle1_208.jpg: 640x576 2 pimples, 15.6ms
# image 70/146 /kaggle/working/acne_dataset/images/test/levle1_210.jpg: 640x576 6 pimples, 15.6ms
# image 71/146 /kaggle/working/acne_dataset/images/test/levle1_222.jpg: 640x576 4 pimples, 15.6ms
# image 72/146 /kaggle/working/acne_dataset/images/test/levle1_247.jpg: 640x576 3 pimples, 15.6ms
# image 73/146 /kaggle/working/acne_dataset/images/test/levle1_253.jpg: 640x576 3 pimples, 15.5ms
# image 74/146 /kaggle/working/acne_dataset/images/test/levle1_257.jpg: 448x640 15 pimples, 13.6ms
# image 75/146 /kaggle/working/acne_dataset/images/test/levle1_261.jpg: 448x640 4 pimples, 13.0ms
# image 76/146 /kaggle/working/acne_dataset/images/test/levle1_264.jpg: 448x640 8 pimples, 12.9ms
# image 77/146 /kaggle/working/acne_dataset/images/test/levle1_266.jpg: 448x640 4 pimples, 15.0ms
# image 78/146 /kaggle/working/acne_dataset/images/test/levle1_288.jpg: 640x576 2 pimples, 16.6ms
# image 79/146 /kaggle/working/acne_dataset/images/test/levle1_295.jpg: 640x576 5 pimples, 15.6ms
# image 80/146 /kaggle/working/acne_dataset/images/test/levle1_300.jpg: 640x576 3 pimples, 15.6ms
# image 81/146 /kaggle/working/acne_dataset/images/test/levle1_321.jpg: 640x576 3 pimples, 15.6ms
# image 82/146 /kaggle/working/acne_dataset/images/test/levle1_335.jpg: 640x576 4 pimples, 15.6ms
# image 83/146 /kaggle/working/acne_dataset/images/test/levle1_345.jpg: 640x576 2 pimples, 15.6ms
# image 84/146 /kaggle/working/acne_dataset/images/test/levle1_371.jpg: 640x576 2 pimples, 15.7ms
# image 85/146 /kaggle/working/acne_dataset/images/test/levle1_378.jpg: 640x576 2 pimples, 15.6ms
# image 86/146 /kaggle/working/acne_dataset/images/test/levle1_381.jpg: 640x576 1 pimple, 15.6ms
# image 87/146 /kaggle/working/acne_dataset/images/test/levle1_402.jpg: 640x576 3 pimples, 15.6ms
# image 88/146 /kaggle/working/acne_dataset/images/test/levle1_404.jpg: 640x576 3 pimples, 15.6ms
# image 89/146 /kaggle/working/acne_dataset/images/test/levle1_411.jpg: 640x576 2 pimples, 15.6ms
# image 90/146 /kaggle/working/acne_dataset/images/test/levle1_421.jpg: 640x576 4 pimples, 15.6ms
# image 91/146 /kaggle/working/acne_dataset/images/test/levle1_427.jpg: 640x576 8 pimples, 15.6ms
# image 92/146 /kaggle/working/acne_dataset/images/test/levle1_43.jpg: 640x576 3 pimples, 15.7ms
# image 93/146 /kaggle/working/acne_dataset/images/test/levle1_44.jpg: 640x576 4 pimples, 15.6ms
# image 94/146 /kaggle/working/acne_dataset/images/test/levle1_446.jpg: 640x576 7 pimples, 15.6ms
# image 95/146 /kaggle/working/acne_dataset/images/test/levle1_45.jpg: 640x576 6 pimples, 15.6ms
# image 96/146 /kaggle/working/acne_dataset/images/test/levle1_467.jpg: 640x576 4 pimples, 15.8ms
# image 97/146 /kaggle/working/acne_dataset/images/test/levle1_471.jpg: 640x576 2 pimples, 15.6ms
# image 98/146 /kaggle/working/acne_dataset/images/test/levle1_472.jpg: 640x576 1 pimple, 15.7ms
# image 99/146 /kaggle/working/acne_dataset/images/test/levle1_485.jpg: 640x576 8 pimples, 15.8ms
# image 100/146 /kaggle/working/acne_dataset/images/test/levle1_509.jpg: 640x576 4 pimples, 15.6ms
# image 101/146 /kaggle/working/acne_dataset/images/test/levle1_56.jpg: 640x576 10 pimples, 15.7ms
# image 102/146 /kaggle/working/acne_dataset/images/test/levle1_575.jpg: 640x576 4 pimples, 15.7ms
# image 103/146 /kaggle/working/acne_dataset/images/test/levle1_584.jpg: 640x576 5 pimples, 15.7ms
# image 104/146 /kaggle/working/acne_dataset/images/test/levle1_585.jpg: 640x576 6 pimples, 15.7ms
# image 105/146 /kaggle/working/acne_dataset/images/test/levle1_597.jpg: 640x576 2 pimples, 15.6ms
# image 106/146 /kaggle/working/acne_dataset/images/test/levle1_599.jpg: 640x576 10 pimples, 15.6ms
# image 107/146 /kaggle/working/acne_dataset/images/test/levle1_600.jpg: 640x576 3 pimples, 15.6ms
# image 108/146 /kaggle/working/acne_dataset/images/test/levle1_607.jpg: 640x576 3 pimples, 15.6ms
# image 109/146 /kaggle/working/acne_dataset/images/test/levle1_615.jpg: 640x576 3 pimples, 15.6ms
# image 110/146 /kaggle/working/acne_dataset/images/test/levle1_625.jpg: 640x576 15 pimples, 15.7ms
# image 111/146 /kaggle/working/acne_dataset/images/test/levle1_626.jpg: 640x576 7 pimples, 15.8ms
# image 112/146 /kaggle/working/acne_dataset/images/test/levle1_67.jpg: 640x576 4 pimples, 15.6ms
# image 113/146 /kaggle/working/acne_dataset/images/test/levle1_78.jpg: 448x640 8 pimples, 13.9ms
# image 114/146 /kaggle/working/acne_dataset/images/test/levle1_8.jpg: 640x544 4 pimples, 51.0ms
# image 115/146 /kaggle/working/acne_dataset/images/test/levle1_84.jpg: 448x640 14 pimples, 13.7ms
# image 116/146 /kaggle/working/acne_dataset/images/test/levle1_97.jpg: 448x640 1 pimple, 12.8ms
# image 117/146 /kaggle/working/acne_dataset/images/test/levle1_98.jpg: 448x640 6 pimples, 12.7ms
# image 118/146 /kaggle/working/acne_dataset/images/test/levle2_109.jpg: 640x576 10 pimples, 16.6ms
# image 119/146 /kaggle/working/acne_dataset/images/test/levle2_124.jpg: 640x576 10 pimples, 15.5ms
# image 120/146 /kaggle/working/acne_dataset/images/test/levle2_13.jpg: 640x576 4 pimples, 15.5ms
# image 121/146 /kaggle/working/acne_dataset/images/test/levle2_153.jpg: 640x576 9 pimples, 15.5ms
# image 122/146 /kaggle/working/acne_dataset/images/test/levle2_156.jpg: 640x576 7 pimples, 15.6ms
# image 123/146 /kaggle/working/acne_dataset/images/test/levle2_158.jpg: 640x576 5 pimples, 15.6ms
# image 124/146 /kaggle/working/acne_dataset/images/test/levle2_159.jpg: 640x576 4 pimples, 15.6ms
# image 125/146 /kaggle/working/acne_dataset/images/test/levle2_16.jpg: 640x480 1 pimple, 13.0ms
# image 126/146 /kaggle/working/acne_dataset/images/test/levle2_163.jpg: 640x576 11 pimples, 16.4ms
# image 127/146 /kaggle/working/acne_dataset/images/test/levle2_172.jpg: 640x576 8 pimples, 15.8ms
# image 128/146 /kaggle/working/acne_dataset/images/test/levle2_177.jpg: 640x576 15 pimples, 15.6ms
# image 129/146 /kaggle/working/acne_dataset/images/test/levle2_22.jpg: 640x480 8 pimples, 13.5ms
# image 130/146 /kaggle/working/acne_dataset/images/test/levle2_30.jpg: 640x544 18 pimples, 17.1ms
# image 131/146 /kaggle/working/acne_dataset/images/test/levle2_45.jpg: 448x640 7 pimples, 13.7ms
# image 132/146 /kaggle/working/acne_dataset/images/test/levle2_53.jpg: 448x640 13 pimples, 12.8ms
# image 133/146 /kaggle/working/acne_dataset/images/test/levle2_59.jpg: 448x640 7 pimples, 12.7ms
# image 134/146 /kaggle/working/acne_dataset/images/test/levle2_87.jpg: 640x576 3 pimples, 16.5ms
# image 135/146 /kaggle/working/acne_dataset/images/test/levle2_96.jpg: 640x576 16 pimples, 15.6ms
# image 136/146 /kaggle/working/acne_dataset/images/test/levle3_0.jpg: 640x480 12 pimples, 12.7ms
# image 137/146 /kaggle/working/acne_dataset/images/test/levle3_12.jpg: 640x480 21 pimples, 11.8ms
# image 138/146 /kaggle/working/acne_dataset/images/test/levle3_131.jpg: 640x576 11 pimples, 16.2ms
# image 139/146 /kaggle/working/acne_dataset/images/test/levle3_3.jpg: 640x480 1 pimple, 12.6ms
# image 140/146 /kaggle/working/acne_dataset/images/test/levle3_40.jpg: 640x512 5 pimples, 42.4ms
# image 141/146 /kaggle/working/acne_dataset/images/test/levle3_50.jpg: 640x640 2 pimples, 17.2ms
# image 142/146 /kaggle/working/acne_dataset/images/test/levle3_55.jpg: 640x512 8 pimples, 12.8ms
# image 143/146 /kaggle/working/acne_dataset/images/test/levle3_67.jpg: 640x480 1 pimple, 13.0ms
# image 144/146 /kaggle/working/acne_dataset/images/test/levle3_73.jpg: 384x640 10 pimples, 60.8ms
# image 145/146 /kaggle/working/acne_dataset/images/test/levle3_75.jpg: 384x640 17 pimples, 10.6ms
# image 146/146 /kaggle/working/acne_dataset/images/test/levle3_92.jpg: 448x640 11 pimples, 13.8ms
# Speed: 3.9ms preprocess, 17.2ms inference, 1.6ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /kaggle/working/runs/detect/predict
# Predictions saved! Check the /kaggle/working/runs/detect/predict/ folder.

# %%
import shutil
from IPython.display import FileLink

# Path to folder and output zip
folder_path = '/kaggle/working/runs'
zip_path = '/kaggle/working/runs.zip'

# Create zip archive
shutil.make_archive('/kaggle/working/runs', 'zip', folder_path)

# Provide download link
FileLink(zip_path)
# Out:
# /kaggle/working/runs.zip
